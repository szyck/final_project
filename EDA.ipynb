# %%
import pandas as pd
import numpy as np
import csv
import sqlite3
from sqlalchemy import create_engine
from sklearn.preprocessing import StandardScaler

# %%
training = pd.read_csv(r'C:\Users\Sam\Desktop\D.A\final_project\data\train.csv')
testing = pd.read_csv(r'C:\Users\Sam\Desktop\D.A\final_project\data\test.csv')
test_df = pd.DataFrame(testing)
train_df = pd.DataFrame(training)
pd.set_option('display.max_columns', None)
test_df.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193        3  16        226      1412  3476    12     7
# 1    0.8        191        5  12        746       857  3895     6     0
# 2    0.9        186        3   4       1270      1366  2396    17    10
# 3    0.5         96        8  20        295      1752  3893    10     0
# 4    0.5        108        6  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
#data_scaler = StandardScaler()
#train_scaled = data_scaler.fit_transform(train_df)
#test_scaled = data_scaler.fit_transform(test_df)
train_df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# ...

# %%
#print(np.mean(train_scaled[:,0]))
# Out:
# 0.0

# %%
# create_table = '''CREATE TABLE train(
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                battery_power INTEGER,
                blue INTEGER,
                clock_speed FLOAT,
                dual_sim BOOLEAN,
                fc INTEGER,
                four_g INTEGER,
                int_memory INTEGER,
                m_dep FLOAT,
                mobile_wt FLOAT,
                n_cores INTEGER,
                pc INTEGER,
                px_height INTEGER,
                px_width INTEGER,
                ram INTEGER,
                sc_h FLOAT,
                sc_w FLOAT,
                talk_time INTEGER,
                three_g BOOLEAN,
                touch_screen BOOLEAN,
                wifi BOOLEAN);
                '''
# Out:
#   File "C:\Users\Sam\AppData\Local\Temp\ipykernel_5436\2443882790.py", line 2
#     id INTEGER PRIMARY KEY AUTOINCREMENT,
#     ^
# IndentationError: unexpected indent

# %%
engine = create_engine("sqlite:///mobile_phones.db")

# %%
train_df.to_sql('phone_training', con=engine)
engine.execute("SELECT * FROM phone_training").fetchall()
# Out:
# [(0, 842, 0, 2.2, 0, 1, 0, 7, 0.6, 188, 2, 2, 20, 756, 2549, 9, 7, 19, 0, 0, 1, 1),
#  (1, 1021, 1, 0.5, 1, 0, 1, 53, 0.7, 136, 3, 6, 905, 1988, 2631, 17, 3, 7, 1, 1, 0, 2),
#  (2, 563, 1, 0.5, 1, 2, 1, 41, 0.9, 145, 5, 6, 1263, 1716, 2603, 11, 2, 9, 1, 1, 0, 2),
#  (3, 615, 1, 2.5, 0, 0, 0, 10, 0.8, 131, 6, 9, 1216, 1786, 2769, 16, 8, 11, 1, 0, 0, 2),
#  (4, 1821, 1, 1.2, 0, 13, 1, 44, 0.6, 141, 2, 14, 1208, 1212, 1411, 8, 2, 15, 1, 1, 0, 1),
#  (5, 1859, 0, 0.5, 1, 3, 0, 22, 0.7, 164, 1, 7, 1004, 1654, 1067, 17, 1, 10, 1, 0, 0, 1),
#  (6, 1821, 0, 1.7, 0, 4, 1, 10, 0.8, 139, 8, 10, 381, 1018, 3220, 13, 8, 18, 1, 0, 1, 3),
#  (7, 1954, 0, 0.5, 1, 0, 0, 24, 0.8, 187, 4, 0, 512, 1149, 700, 16, 3, 5, 1, 1, 1, 0),
#  (8, 1445, 1, 0.5, 0, 0, 0, 53, 0.7, 174, 7, 14, 386, 836, 1099, 17, 1, 20, 1, 0, 0, 0),
#  (9, 509, 1, 0.6, 1, 2, 1, 9, 0.1, 93, 5, 15, 1137, 1224, 513, 19, 10, 12, 1, 0, 0, 0),
#  (10, 769, 1, 2.9, 1, 0, 0, 9, 0.1, 182, 5, 1, 248, 874, 3946, 5, 2, 7, 0, 0, 0, 3),
# ...

# %%
test_df.to_sql('phone_testing', con=engine)
engine.execute("SELECT * FROM phone_training").fetchall()
# Out:
# [(0, 842, 0, 2.2, 0, 1, 0, 7, 0.6, 188, 2, 2, 20, 756, 2549, 9, 7, 19, 0, 0, 1, 1),
#  (1, 1021, 1, 0.5, 1, 0, 1, 53, 0.7, 136, 3, 6, 905, 1988, 2631, 17, 3, 7, 1, 1, 0, 2),
#  (2, 563, 1, 0.5, 1, 2, 1, 41, 0.9, 145, 5, 6, 1263, 1716, 2603, 11, 2, 9, 1, 1, 0, 2),
#  (3, 615, 1, 2.5, 0, 0, 0, 10, 0.8, 131, 6, 9, 1216, 1786, 2769, 16, 8, 11, 1, 0, 0, 2),
#  (4, 1821, 1, 1.2, 0, 13, 1, 44, 0.6, 141, 2, 14, 1208, 1212, 1411, 8, 2, 15, 1, 1, 0, 1),
#  (5, 1859, 0, 0.5, 1, 3, 0, 22, 0.7, 164, 1, 7, 1004, 1654, 1067, 17, 1, 10, 1, 0, 0, 1),
#  (6, 1821, 0, 1.7, 0, 4, 1, 10, 0.8, 139, 8, 10, 381, 1018, 3220, 13, 8, 18, 1, 0, 1, 3),
#  (7, 1954, 0, 0.5, 1, 0, 0, 24, 0.8, 187, 4, 0, 512, 1149, 700, 16, 3, 5, 1, 1, 1, 0),
#  (8, 1445, 1, 0.5, 0, 0, 0, 53, 0.7, 174, 7, 14, 386, 836, 1099, 17, 1, 20, 1, 0, 0, 0),
#  (9, 509, 1, 0.6, 1, 2, 1, 9, 0.1, 93, 5, 15, 1137, 1224, 513, 19, 10, 12, 1, 0, 0, 0),
#  (10, 769, 1, 2.9, 1, 0, 0, 9, 0.1, 182, 5, 1, 248, 874, 3946, 5, 2, 7, 0, 0, 0, 3),
# ...
